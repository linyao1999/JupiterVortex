# %%
import numpy as np 
import h5py 
import matplotlib.pyplot as plt

# %%
# with h5py.File('debug.h5', 'r') as f:
#     Psi1 = f["tasks/Psi1"][:].flatten()
#     Psi2 = f["tasks/Psi2"][:].flatten()
#     U1   = f["tasks/U1"][:]
#     U2   = f["tasks/U2"][:]  
#     Q1   = f["tasks/Q1"][:].flatten()
#     Q2   = f["tasks/Q2"][:].flatten()
#     r    = f["tasks/r"][:].flatten()

with h5py.File('debug.h5', 'r') as f:
    Psi1 = f["tasks/Psi1"][:]
    Psi2 = f["tasks/Psi2"][:]
    gradPsi1   = f["tasks/gradPsi1"][:]
    skewgradPsi1   = f["tasks/skewgradPsi1"][:]  
    lapPsi1   = f["tasks/lapPsi1"][:]
    # Q1   = f["tasks/Q1"][:].flatten()
    r    = f["tasks/r"][:]
    phi  = f["tasks/phi"][:]
    x    = f["tasks/x"][:]
    y  = f["tasks/y"][:]

# %%
fig, ax = plt.subplots(1,1, figsize=(3,3))
# im = ax.pcolormesh(x, y, Psi1- np.cos(6 * phi) - (r**2))
im = ax.pcolormesh(x[:,:], y[:,:], gradPsi1[0,:,:] + 6 * np.sin(6 * phi)/r[0,:])
# im = ax.pcolormesh(x, y, gradPsi1[1,:,:] - (np.cos(6 * phi)*r))
# im = ax.pcolormesh(x, y, skewgradPsi1[0,:,:] - np.cos(6 * phi)*r)
# im = ax.pcolormesh(x, y, skewgradPsi1[1,:,:] - 3 * np.sin(6 * phi)*r)
# truth = -2 * np.sin(6*phi) - 18 * np.cos(6 * phi) * (r * 0 + 1)
# im = ax.pcolormesh(x[:,3:-3], y[:,3:-3], lapPsi1[:,3:-3] - truth[:,3:-3])

# n = np.argmax(np.abs(lapPsi1[:,3:-3] - truth[:,3:-3]))
# x_max = x[:,3:-3].flatten()[n]
# y_max = y[:,3:-3].flatten()[n]
# ax.scatter(x_max, y_max, color='red', marker='x', s=60)

plt.colorbar(im)
# Out:
# /tmp/ipykernel_7568/153496106.py:3: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax.pcolormesh(x[:,:], y[:,:], gradPsi1[0,:,:] + 6 * np.sin(6 * phi)/r[0,:])

# %%
fig, ax = plt.subplots(1,1, figsize=(3,3))
# im = ax.pcolormesh(x, y, Psi1- 0.5 * np.cos(6 * phi) * (r**2))
# im = ax.pcolormesh(x, y, gradPsi1[0,:,:] + 3 * np.sin(6 * phi)*r)
# im = ax.pcolormesh(x, y, gradPsi1[1,:,:] - (np.cos(6 * phi)*r))
# im = ax.pcolormesh(x, y, skewgradPsi1[0,:,:] - np.cos(6 * phi)*r)
# im = ax.pcolormesh(x, y, skewgradPsi1[1,:,:] - 3 * np.sin(6 * phi)*r)
# truth = -2 * np.sin(6*phi) - 18 * np.cos(6 * phi) * (r * 0 + 1)
# im = ax.pcolormesh(x[:,3:-3], y[:,3:-3], lapPsi1[:,3:-3] - truth[:,3:-3])

# n = np.argmax(np.abs(lapPsi1[:,3:-3] - truth[:,3:-3]))
# x_max = x[:,3:-3].flatten()[n]
# y_max = y[:,3:-3].flatten()[n]
# ax.scatter(x_max, y_max, color='red', marker='x', s=60)

plt.colorbar(im)
# Out:
# /tmp/ipykernel_6377/2775919088.py:8: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax.pcolormesh(x[:,3:-3], y[:,3:-3], lapPsi1[:,3:-3] - truth[:,3:-3])

# %%
fig, ax = plt.subplots(1,1, figsize=(3,3))
ax.plot(r[0,2:-4].flatten(), lapPsi1[0,2:-4], label='Psi1')
# ax.plot(r.flatten(), truth,'x', label='true')
# ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
# ax.plot(r, lapPsi1, label='Psi1')
# ax.plot(r, 4.5 * r, 'x', label='true')
# ax.plot(r, skewgradPsi1[0,0,:], label='Psi1')
# ax.plot(r, 1.5 * (r**2), 'x', label='true')
# ax.plot(r, gradPsi1[1,0,:], label='Psi1')
# ax.plot(r, 1.5 * (r**2), 'x', label='true')
# ax.plot(r, Psi1, label='Psi1')
# ax.plot(r, 0.5 * (r**3), 'x', label='true')

# %%
fig, ax = plt.subplots(1, 2, figsize=(6, 6))
cmap = 'Blues'
ax[0].plot(r, Psi1, label='Psi1')
ax[0].plot(r, 0.5 * r * r, 'x', label='real')
ax[0].plot(r, Psi2, label='Psi2')
ax[0].legend()

ax[1].plot(r, U1[0,0,:], label='U1')
ax[1].plot(r, r, 'x', label='real')
ax[1].plot(r, U2[0,0,:], label='U2')

# ax[1].plot(r, Q1, label='U1')
# # ax[1].plot(r, r, 'x', label='real')
# ax[1].plot(r, Q2, label='U2')

ax[1].legend()
